# %% [markdown]
# # U-Skate World
#
# ## A reaction diffusion system in the Gray-Scott framework that supports stable localized moving patterns, aka gliders
#
# ![](../assets/uskate_uskate_summary.png)
#
# ### Overview
#
# A [reaction-diffusion system](https://en.wikipedia.org/wiki/Reaction%E2%80%93diffusion_system) is a mathematical model of chemical interactions based on diffusion and reaction of one or more chemical species. The [Gray-Scott](https://groups.csail.mit.edu/mac/projects/amorphous/GrayScott/) system is a reaction diffusion system that models the interaction of two chemical species, $U$ and $V$.
#
# The Gray-Scott system models the conversion of species $U$ to species $V$, catalyzed by two molecules of $V$, yielding a total of $3V$.
#
# $$
# U + 2V \rightarrow 3V
# $$
#
# The Gray-Scott update equations include terms for diffusion, reaction, and addition or removal of each species (for example, by diffusion across a permeable membrane from a reservoir).
#
# ### Updates
#
# Equations to update concentrations of $u$ and $v$ have the same form. Three terms describe diffusion of the species, reaction with itself and the other species, and addition/removal from the reaction chamber.
#
# $$
# \frac{\partial u}{\partial t} = \frac{1}{\Delta x^2} D_u \nabla^2 u - uv^2 + F(1-u)
# $$
#
# $$
# \frac{\partial v}{\partial t} = \frac{1}{\Delta x^2}D_v \nabla^2 v + uv^2 - (F+k)v
# $$
#
# The diffusion terms shared the form $ \frac{1}{\Delta x^2} D_s \nabla^2 s$, where $\Delta x$ is spatial resolution, $D_s$ is the diffusion constant for species $s$, and $\nabla^2 s$ is the Laplacian of $s$ and captures the rate of change of $s$ in 2-dimensions.
#
# The reaction term is the same, $uv^2$. Species $u$ is depleted by the reaction term and the concentration of $v$ is increased.
#
# Eventually, the entire concentration of $u$ would be consumed and converted to $v$. The third term $F(1-u)$ simulates the addition of more $u$ from a limitless reservoir of pure $u$. The buildup in the concentration of $v$ is lessened by $- (F+k)v$, or $(F+k)(0-v)$, written in similar form to the addition term for $u$. In a physical system, this could be approximated by a permeable membrane separating a flow reservoir of pure $u$ and a 2-dimensional reaction chamber, where $v$ diffuses into and ample $u$ diffuses out of. $F$ is sometimes called the 'feed rate' and $k$, the difference between transport of $u$ and $v$ into/out of the reaction chamber, is sometimes called the 'decay' or 'kill' rate.
#
# Once the rate of change is computing, the change in concentrations $u$ and $v$ follows the Euler method:
#
# $$
# u_{t+\Delta t} = u_t + \Delta t * \frac{\partial u}{\partial t}
# $$
#
# $$
# v_{t+\Delta t} = v_t + \Delta t * \frac{\partial v}{\partial t}
# $$
#
# ### Diffusion
#
# To calculate the diffusion terms in a Gray-Scott system, we need the spatial resolution $\Delta x$, the diffusion constants $D_u$ and $D_v$, and a discrete approximation of the Laplacian $\nabla^2$.
#
# Many Gray-Scott implementations use a stencil kernel, equivalent to the finite difference method of subtracting the weighted value of a pixel from the weighted value of its neighbors. For example, the five-point stencil looks like:
#
# $$
# K_{D5} = \left[
#         \begin{array}{ c c c }
#             0 \hspace{1.0cm} 1 \hspace{1.0cm} 0 \\
#             1 \hspace{0.5cm} -4 \hspace{0.9cm} 1 \\
#             0 \hspace{1.0cm} 1 \hspace{1.0cm} 0 \\
#         \end{array}
#         \right]
# $$
#
# and a nine-point stencil:
#
# $$
# K_{D9} = \left[
#         \begin{array}{ c c c }
#             1 \hspace{1.0cm} 2 \hspace{1.0cm} 1 \\
#             2 \hspace{0.35cm} -12 \hspace{0.75cm} 2 \\
#             1 \hspace{1.0cm} 2 \hspace{1.0cm} 1 \\
#         \end{array}
#         \right]
# $$
#
# The kernels are then convolved with the grid of $u$ or $v$ concentrations to approximate the Laplacian. To keep the magnitude of the results the same, the kernels can be normalized by the sum of absolute values of the stencil kernel weights.
#
# Another approach, and the one used in _Disco Gliders_, is to approximate the Laplacian by first convolving with a narrow Gaussian. This mimics the technique, common in image processing applications, of smoothing the grid before applying a Laplacian.
#
# $$
# LoG(r) = \frac{1}{\pi \sigma^2}(1 - \frac{r^2}{2\sigma^2}) e^{-\frac{r^2}{2\sigma^2}}
# $$
#
# The advantage of the Laplacian of Gaussian approach is that the kernel can be scaled to arbitrary size. However, in my hands U-Skate World only supports gliders in the default case of a 3x3 kernel.
#
# The Laplacian of Gaussian produces a kernel with similar values to the nine-point stencil (normalized by the sum of absolute values).
#
# $$
# K_{log} \approx \left[
#         \begin{array}{ c c c }
#             0.0419 \hspace{1.0cm} 0.0831 \hspace{1.0cm} 0.0419 \\
#             0.0831 \hspace{0.6cm} -0.500 \hspace{1.1cm} 0.0831 \\
#             0.0419 \hspace{1.0cm} 0.0831 \hspace{1.0cm} 0.0419 \\
#         \end{array}
#         \right]
# $$
#
# Adapting U-Skate World to use the Laplacian of Gaussian involved modifying $\Delta x$ from $\frac{1}{102} = 0.009804$ to a value of $0.00303$. The parameters used for my implementation are $\Delta x=0.00303$, $D_u =2.00 * 10^-5$, $D_v = 1.00 * 10^{-5}$, $F = 0.0620 $, $k =0.0609$
#
# <!-- Image link to be used after making repo public -->
# <!-- <img src="https://raw.github.com/riveSunder/DiscoGliders/assets/glaberish_4.gif"> -->
#
# <!-- local image -->
# ![](../assets/uskate_4.gif)

# %%
import os
import time

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F


import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams["animation.embed_limit"] = 128

import skimage
import skimage.io as sio
import skimage.transform

import yuca
from yuca.ca.neural import NCA
from yuca.ca.continuous import CCA
from yuca.ca.reaction_diffusion import RxnDfn
from yuca.cppn import CPPN

from yuca.zoo.librarian import Librarian

import IPython

from importlib import reload
reload(yuca)
reload(yuca.ca)

# %%
def plot_grid(grid, my_cmap=plt.get_cmap("magma"), title="U-Skate animation", vmin=0.0, vmax=1):

    global subplot_0
    
    fig, ax = plt.subplots(1,1, figsize=(4.5,4.5), facecolor="white")

    # TODO invert cmap
    
    grid_display = my_cmap(grid[0,0])[:,:,0:3]
    
    subplot_0 = ax.imshow(grid_display, interpolation="nearest")
    
    fig.suptitle(title, fontsize=8)

    ax.set_yticklabels('')
    ax.set_xticklabels('')
    
    plt.tight_layout()

    return fig, ax

def update_fig(i):

    global subplot_0    
    global grid
    global speedup
    
    my_cmap=plt.get_cmap("magma")
    
    for ii in range(speedup):
        grid = uskate(grid)
    
    grid_display = my_cmap(grid[0,0])[:,:,0:3]
    
    subplot_0.set_array(grid_display)
        
    plt.tight_layout()

# %%
lib = Librarian(verbose=False)
uskate = RxnDfn()

save_figs = False

num_frames = 100
speedup = 300
grid_dim = 246

# %%
pattern_name = "uskate_glider001"
p, m = lib.load(pattern_name)

grid = uskate.initialize_grid(dim=grid_dim)

pattern_name = "uskate_berrycup001"
p, m = lib.load(pattern_name)
grid[0,:,:p.shape[-2],:p.shape[-1]] = torch.tensor(p)

pattern_name = "uskate_glider001"
p, m = lib.load(pattern_name)
grid[0,:,:p.shape[-2],120:120+p.shape[-1]] = torch.tensor(p)

pattern_name = "uskate_daedalus001"
p, m = lib.load(pattern_name)
grid[0,:,:p.shape[-2],160:160+p.shape[-1]] = torch.tensor(p)

fig, ax = plot_grid(grid)
plt.show()

if save_figs:
    save_path = os.path.join("..","assets", "uskate_4.gif")
    matplotlib.animation.FuncAnimation(fig, update_fig, frames=num_frames, interval=10).save(save_path)
    
IPython.display.HTML(\
        matplotlib.animation.FuncAnimation(fig, update_fig, frames=num_frames, interval=10).to_jshtml())

# %% [markdown]
# # Discretization Experiments

# %%
number_samples = 3
number_steps = 262144


my_dx_0 = uskate.get_dx()
min_dx = uskate.get_dx() / 2
max_dx = (uskate.get_dx() - min_dx) + my_dx_0

my_dxs = np.arange(min_dx, max_dx, \
                  (max_dx-min_dx) / number_samples)

my_dts = np.arange(1/number_samples,\
                   1.+ 1/number_samples, \
                   1/number_samples)

pattern_names = ["uskate_berrycup001",\
        "uskate_daedalus001",\
        "uskate_glider001"]

t0 = time.time()

for pattern_name in pattern_names:
    p, m = lib.load(pattern_name)
    for my_dt in my_dts:

        for my_dx in my_dxs:
            uskate = RxnDfn()
            uskate.set_dt(my_dt)
            uskate.set_dx(my_dx)

            grid = uskate.initialize_grid()
            grid[0,:,:p.shape[-2],:p.shape[-1]] = torch.tensor(p)

            t1 = time.time()
            for step in range(number_steps):

                grid = uskate(grid)

            t2 = time.time()

            my_dx *= 3

            print(f"run time {t2-t1:.3f}, total time elapsed: {t2-t0:.3f}")

            fig, ax = plot_grid(grid)

            fig.suptitle(f"dt = {uskate.get_dt():.3f}, dx ={uskate.get_dx():.3e} \n step {step}")
            plt.tight_layout()
            fig_name = f"{pattern_name}_dx{uskate.get_dt():.3f}_{uskate.get_dx():.3e}"
            fig_name = fig_name.replace(".","x") + ".png"
            fig_name = os.path.join("..","results", "uskate_results_assets", fig_name)
            print(f"saving to {fig_name}")
            plt.savefig(fig_name)

            plt.show()

# %%
# make figure from saved end-states

uskate= RxnDfn()

number_samples = 20

my_dx_0 = uskate.get_dx()
min_dx = uskate.get_dx() / 50
max_dx = (uskate.get_dx() - min_dx) + my_dx_0

dxs = np.arange(min_dx, max_dx, \
                  (max_dx - min_dx) / number_samples)


ddt=0.04
dts = np.arange(ddt,1.0+ddt,ddt)
dts.shape, dxs.shape

dtdt, dxdx = np.meshgrid(dts,dxs)

berrycup_support = np.array([2.733e-3, 3.03e-3, 3.327e-3, 3.624e-3])
daedalus_support = np.array([2.733e-3, 3.03e-3, 3.327e-3, 3.624e-3])
uskate_support = np.array([2.733e-3, 3.03e-3, 3.327e-3, 3.624e-3, 3.921e-3])


pattern_names = ["uskate_daedalus001",\
        "uskate_glider001",\
        "uskate_berrycup001"]

pattern_titles = ["U-Skate Daedalus",\
                  "U-Skate U-Skate glider",\
                 "U-Skate BerryCup"]

t0 = time.time()

image_map = [None, None, None]

for hh, pattern_name in enumerate(pattern_names):
    
    image_map = [None, None, None]
    for ii, dt in enumerate(dts):
        for jj, dx in enumerate(dxs):
            
            fig_name = f"{pattern_name}_step262144_dx{dt:.3f}_{dx:.3e}"

            fig_name = fig_name.replace(".","x") + ".png"
            fig_name = os.path.join("..","results", "uskate_results_assets", fig_name)
            if os.path.exists(fig_name):
                img = sio.imread(fig_name)[68:-20,44:-44,:]
            else:
                print("f{fig_name} doesn't exist")
                img = np.zeros((362,362,4))
                
            img = skimage.transform.resize(img, [elem // 4 for elem in img.shape[:2]])
                
            if jj == 0:
                if ii > 0:
                    if image_map[hh] is None:
                        image_map[hh] = temp_img_map
                    else:
                        image_map[hh] = np.append(image_map[hh], temp_img_map, axis=1)
                    
                temp_img_map = img
            else:
                temp_img_map = np.append(temp_img_map, img, axis=0)
             
    fig, ax =  plt.subplots(1,1,figsize=(10,10))

    ax.imshow(image_map[hh])

    xtick_start = image_map[hh].shape[1] / 25 / 2
    ytick_start = image_map[hh].shape[0] / 20 / 2

    ax.set_xticks(np.arange(xtick_start,image_map[hh].shape[1], image_map[hh].shape[1] / 25))
    ax.set_yticks(np.arange(ytick_start,image_map[hh].shape[0], image_map[hh].shape[0] / 20))
    dt_labels = [f"{dt:.2f}" for dt in dts]
    dx_labels = [f"{dx:.3e}" for dx in dxs]
    ax.set_xticklabels(dt_labels, rotation=45)
    ax.set_yticklabels(dx_labels)

    ax.set_xlabel("$\Delta t$", fontsize=28)
    ax.set_ylabel("$\Delta x$", fontsize=28)
    
    ax.set_title(f"{pattern_titles[hh]}\n stability w.r.t $\Delta x$ and $\Delta t$", fontsize=36)


    save_to = os.path.join("..","assets", f"{pattern_name}_dxdt_summary.png")
    plt.savefig(save_to)

    plt.show()
